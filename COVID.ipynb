# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Latest Covid-19 India Status.csv')

# %%
data.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7525      14        7382     129
# 1       Andhra Pradesh      1952513   22358     1916914   13241
# 2    Arunachal Pradesh        45703    4465       41025     213
# 3                Assam       557437   15726      536597    5114
# 4                Bihar       724390     530      714223    9637
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.19                98.10             1.71
# 1              1.15                98.18             0.68
# 2              9.77                89.76             0.47
# 3              2.82                96.26             0.92
# 4              0.07                98.60             1.33

# %%
data.shape
# Out:
# (36, 8)

# %%
df=data.copy()

# %%
sns.set(rc={'figure.figsize':(15,10)})

# %%
ax= sns.barplot(x='State/UTs',y='Total Cases',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Active',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Discharged',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Deaths',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Active Ratio (%)',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Discharge Ratio (%)',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ax= sns.barplot(x='State/UTs',y='Death Ratio (%)',data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
